# %%
def is_https(url):
    parsed_url = urlparse(url)
    return parsed_url.scheme == "https"

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse

def is_https(url):
    parsed_url = urlparse(url)
    return parsed_url.scheme == "https"
 
url = 'https://www.zoho.com/deluge/help/data-access/update-records.html#overview'
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text, 'html.parser')

urls = []
for link in soup.find_all('a'):
    ur = link.get('href')
#     print(ur)
    if(is_https(ur)):
        print(ur)
# Out:
# https://deluge.zoho.com/learndeluge#Welcome

# %%
import requests
from bs4 import BeautifulSoup
 
 
url = 'https://www.zoho.com/deluge/help/data-access/update-records.html#overview'
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text, 'html.parser')
 
urls = []
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #overview
# #syntax
# #table
# #mind
# #example
# None
# /deluge/help/fetch-records/fetch-collection-records.html
# None
# /deluge/help/collection-variable.html
# /deluge/help/creator-field-datatype.html
# None
# /deluge/help/crm/create-record.html#Response
# /deluge/help/crm/get-records.html#Response
# /deluge/help/recruit/create-record.html#Fail
# /deluge/help/recruit/fetch-records.html#Example
# /deluge/help/salesforce/create-record.html#Response
# /deluge/help/salesforce/fetch-records.html#Response
# /deluge/help/books/create-record.html#Response
# /deluge/help/books/fetch-records.html#Response
# /deluge/help/quickbooks/create-record.html#Response
# /deluge/help/quickbooks/fetch-records.html#Response
# None
# https://deluge.zoho.com/learndeluge#Welcome

# %%
def solve(url,n,save_dir):
    if(n==1):
        return
    reqs = requests.get(url)
    soup = BeautifulSoup(reqs.text, 'html.parser')

    urls = []
    for link in soup.find_all('a'):
        ur = link.get('href')
        print(ur)
        if(is_https(ur)):
#             print(save_dir)
            
            solve(ur,n+1,save_dir+str(n))
    return

save_dir = <Add directory>>
 
url = <<add url here>> 

solve(url,0,save_dir)
# Out:
# /deluge/help/functions/common/encodeurl.html
# /deluge/help/functions/common/getjson.html
# https://deluge.zoho.com/learndeluge#Welcome

# %%
# print(str(1))
# Out:
# 1

# %%
import requests
import os
import json
i=0

def hisurl(ur):
    url = "https://api.doppio.sh/v1/render/pdf/sync"
    
#     print("hiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii",ur)
    payload = json.dumps({
      "page": {
        "pdf": {
          "printBackground": True
        },
        "goto": {
          "url": ur
        }
      }
    })
    headers = {
      'Authorization': 'Bearer <<add token from api.doppio>>',
      'Content-Type': 'application/json'
    }

    
    response = requests.request("POST", url, headers=headers, data=payload)

    response_data = response.json()  # Convert response to dictionary

    # Extract documentUrl
    pdf_url = response_data.get("documentUrl")
    return pdf_url


# hisurl('https://www.zoho.com/deluge/help/data-access/add-record.html')
    
def download_pdf(url, save_path):
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()  # Raise an error for bad responses
        with open(save_path, "wb") as file:
            for chunk in response.iter_content(chunk_size=1024):  # Download in chunks
                file.write(chunk)
        print(f"PDF saved to {save_path}")
    except requests.RequestException as e:
        print(f"Failed to download {url}: {e}")
    
def solve(url,n,save_dir,i):
    if(n==3):
        return
    reqs = requests.get(url)
    soup = BeautifulSoup(reqs.text, 'html.parser')

    my_list = []  
#     i=0

    for j,link in enumerate(soup.find_all('a')):
        ur = link.get('href')
#         print(j)
        if(is_https(ur)):
            
            print(save_dir)
            print(ur)
#             pdurl = hisurl(ur)
# #             print(pdurl)
#             i=i+1
#             print("assssssssssss",save_dir)
#             create_folder(save_dir)
#             filename = f"document_{i+1}.pdf"  # Change filename format if needed
#             save_path = os.path.join(save_dir, filename)
#             download_pdf(pdurl, save_path)
            solve(ur,n+1,save_dir+"\\"+str(j),i)
            
    
    return

save_dir = "C:\\Users\\krism\\OneDrive\\Documents\\dedocfinal\\built-in-functions"
# https://www.zoho.com/deluge/help/built-in-functions.html
 
url = 'https://www.zoho.com/deluge/help/built-in-functions.html' 

# u=hisurl(url)
# create_folder(save_dir)
# filename = f"document_{i+1}.pdf"  # Change filename format if needed
# save_path = os.path.join(save_dir, filename)
# download_pdf(u,save_path)
# save_dir = save_dir+"\\"+"re"
solve(url,0,save_dir,i)
# Out:
# C:\Users\krism\OneDrive\Documents\dedocfinal\built-in-functions
# https://www.zoho.com/deluge/help/functions/collection.html
# C:\Users\krism\OneDrive\Documents\dedocfinal\built-in-functions\0
# https://deluge.zoho.com/learndeluge#Welcome
# C:\Users\krism\OneDrive\Documents\dedocfinal\built-in-functions\0\23
# https://www.zoho.com/deluge/resources.html
# C:\Users\krism\OneDrive\Documents\dedocfinal\built-in-functions
# https://www.zoho.com/deluge/help/functions/conversion.html
# C:\Users\krism\OneDrive\Documents\dedocfinal\built-in-functions\1
# https://deluge.zoho.com/learndeluge#Welcome
# C:\Users\krism\OneDrive\Documents\dedocfinal\built-in-functions\1\8
# https://www.zoho.com/deluge/resources.html
# C:\Users\krism\OneDrive\Documents\dedocfinal\built-in-functions
# https://www.zoho.com/deluge/help/functions/date-time.html
# C:\Users\krism\OneDrive\Documents\dedocfinal\built-in-functions\2
# https://www.zoho.com/deluge/help/functions/common/tostring.html
# ...

# %%
import requests
import json

url = "https://api.doppio.sh/v1/render/pdf/sync"

payload = json.dumps({
  "page": {
    "pdf": {
      "printBackground": True
    },
    "goto": {
      "url": "https://www.zoho.com/deluge/help/data-access/add-record.html"
    }
  }
})
headers = {
  'Authorization': 'Bearer 67e1fcf92
    1e5998bd7284ad3',
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

response_data = response.json()  # Convert response to dictionary

# Extract documentUrl
pdf_url = response_data.get("documentUrl")

if pdf_url:
    print(f"PDF URL: {pdf_url}")
else:
    print("Failed to extract documentUrl")
# Out:
# PDF URL: https://storage.googleapis.com/tmp2.doppio.sh/doppioreq_b03ea760-efb5-4949-893a-fb4f7a6e3505-1739507322096.pdf

# %%
from pathlib import Path

def create_folder(path):
    folder = Path(path)
    folder.mkdir(parents=True, exist_ok=True)  # Creates folder if it doesn't exist
    print(f"Folder '{path}' is ready!")

# %%
create_folder("C:\\Users\\krism\\OneDrive\\Documents\\DelugeDocument\\0")
# Out:
# Folder 'C:\Users\krism\OneDrive\Documents\DelugeDocument\0' is ready!
